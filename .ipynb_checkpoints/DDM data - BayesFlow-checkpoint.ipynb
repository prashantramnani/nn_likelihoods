# %%
import sys
# sys.path.append('./BayesFlow')

import tensorflow as tf
print(tf.__version__)
from tensorflow.keras.regularizers import l2
import tensorflow.contrib.eager as tfe
import tensorflow_probability as tfp
import numpy as np
import seaborn as sns
from scipy import stats
import pandas as pd
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import pickle

from functools import partial
from tqdm.notebook import tqdm
# print(tqdm.__version__)

from BayesFlow.models import DeepConditionalModel, InvariantNetwork
from BayesFlow.losses import maximum_likelihood_loss
from BayesFlow.inn_utils import train_online_ml
# from viz import plot_losses, plot_metrics_params


from sklearn.neighbors import KernelDensity
import random
import multiprocessing as mp
import psutil
import pickle
import os
import re
import scipy as scp
from scipy.stats import gamma


import cddm_data_simulation as cds
import kde_training_utilities as kde_util
import kde_class as kde
import boundary_functions as bf
# Out:
# 1.15.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-fa9c26d2dbf4> in <module>
#      36
#      37
# ---> 38 import cddm_data_simulation as cds
#      39 import kde_training_utilities as kde_util
#      40 import kde_class as kde
#
# ModuleNotFoundError: No module named 'cddm_data_simulation'

# %%
np.set_printoptions(suppress=True)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tf.enable_eager_execution()

# %%
def gaussian(batch_size):
    mean = np.random.uniform(0,1,batch_size)
    var = np.random.uniform(0,2,batch_size)
    
    X_train = []
    
    for i in range(batch_size):
        a = np.random.normal(mean[i], var[i], 1000)
        X_train.append(a)
        
    X_train = np.array(X_train)    
    
    param = np.concatenate((mean.reshape(-1, 1), var.reshape(-1, 1)), axis=1)
    
    return tf.convert_to_tensor(X_train, dtype=tf.float32), tf.convert_to_tensor(param, dtype=tf.float32)

# %%
out = cds.ddm_flexbound(v=0, a=1, w=0.5,
                    ndt = 0.5,
                    delta_t = 0.001, 
                    s = np.sqrt(2),
                    max_t = 20,
                    n_samples = 5000,
                    boundary_fun = bf.constant,
                    boundary_multiplicative = True, 
                    boundary_params = {})
                    #boundary_params = {"theta": 0.01})

data = np.concatenate((out[0].T, out[1].T),axis=1) 
data.shape
df = pd.DataFrame(
    out[0],
    columns = ['rt'])

df.plot.hist(bins=100, alpha=0.5)
# a = []
# a.append(data)
# print(a)

# %%
def ddm(batch_size):
    a = np.random.uniform(1,4,batch_size)
    v = np.random.uniform(0,0.5,batch_size)

    X_train = []

    for i in range(batch_size):
        out = cds.ddm_flexbound(v[i], a[i], w=0.5,
                            ndt = 0.5,
                            delta_t = 0.001, 
                            s = np.sqrt(2),
                            max_t = 20,
                            n_samples = 500,
                            boundary_fun = bf.constant,
                            boundary_multiplicative = True, 
                            boundary_params = {})
                            #boundary_params = {"theta": 0.01})
#         data = np.concatenate((out[0].T, out[1].T), axis=1).reshape(1000,)    
#         X_train.append(data)    
        X_train.append(out[0].reshape(500, ))
        
    X_train = np.array(X_train)         
    param = np.concatenate((a.reshape(-1, 1), v.reshape(-1, 1)), axis=1)
    
    return tf.convert_to_tensor(X_train, dtype=tf.float32), tf.convert_to_tensor(param, dtype=tf.float32)
a, b = ddm(10)      
print(a.shape)
# Out:
# (10, 500)

# %%
def load_model_and_opt(n_inv_blocks, global_step):
    """Loads a GMM model given the number of invertible blocks."""
    
    # Create model
    model = DeepConditionalModel(inv_meta, n_inv_blocks, theta_dim, summary_net=None, permute=True)
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    
    # Checkpoint model
    checkpoint = tf.train.Checkpoint(step=global_step, optimizer=optimizer, net=model)
    manager = tf.train.CheckpointManager(checkpoint, './checkpoints/ddm_{}'.format(n_inv_blocks), max_to_keep=2)
    checkpoint.restore(manager.latest_checkpoint)
    
    return model, optimizer, manager

# %%
def train_model(n_inv_blocks):
    """
    Runs the Gausian Distribution
    """
    
    model, optimizer, manager = load_model_and_opt(n_inv_blocks, global_step)
    
    for ep in range(1, epochs+1):
        with tqdm(total=iterations_per_epoch, desc='Training epoch {}'.format(ep)) as p_bar:

            # Run training loop
            train_online_ml(model, optimizer, ddm, iterations_per_epoch, 
                            batch_size, p_bar=p_bar, clip_value=clip_value, global_step=global_step, 
                            transform=None, n_smooth=100)
            
            manager.save()

# %%
inv_meta = {
    'n_units': [128, 128, 128],
    'activation': 'elu',
    'w_decay': 0.0,
    'initializer': 'glorot_uniform'
}

n_inv = 8
theta_dim = 2
# params_names = [r'$\mu_{}$'.format(i+1) for i in range(theta_dim)]
global_step = tf.Variable(0, dtype=tf.int32)
batch_size = 50
epochs = 20
iterations_per_epoch = 100
n_samples_posterior = 2000
starter_learning_rate = 0.001
decay_steps = 1000
decay_rate = .99
clip_value = 5.
learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 
                                           decay_steps, decay_rate, staircase=True)

# %%
train_model(n_inv)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Training epoch 1', style=ProgressStyle(description_width=…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-0e0bc86de538> in <module>
# ----> 1 train_model(n_inv)
#
# <ipython-input-28-90e88462cf19> in train_model(n_inv_blocks)
#      12             train_online_ml(model, optimizer, ddm, iterations_per_epoch,
#      13                             batch_size, p_bar=p_bar, clip_value=clip_value, global_step=global_step,
# ---> 14                             transform=None, n_smooth=100)
#      15
#      16             manager.save()
#
# ~/Projects/Intern/HDDM_nn/nn_likelihoods/inn_utils.py in train_online_ml(model, optimizer, data_generator, iterations, batch_size, p_bar, clip_value, global_step, transform, n_smooth)
#      48         with tf.GradientTape() as tape:
#      49             # Generate data and parameters
# ---> 50             X_batch, theta_batch = data_generator(batch_size)
#      51             # Apply some transformation, if specified
#      52             if transform:
#
# <ipython-input-26-03956d35f7f6> in ddm(batch_size)
#      14                             boundary_fun = bf.constant,
#      15                             boundary_multiplicative = True,
# ---> 16                             boundary_params = {})
#      17                             #boundary_params = {"theta": 0.01})
#      18 #         data = np.concatenate((out[0].T, out[1].T), axis=1).reshape(1000,)
#
# KeyboardInterrupt:

# %%
model, _, _ = load_model_and_opt(8, global_step)

# a = np.random.normal(0, 1.7, 1000).reshape(1, -1)
# a = np.random.uniform(1,4,batch_size)
# v = np.random.uniform(0,0.5,batch_size)



out = cds.ddm_flexbound(v=0.1, a=2, w=0.5,
                            ndt = 0.5,
                            delta_t = 0.001, 
                            s = np.sqrt(2),
                            max_t = 20,
                            n_samples = 500,
                            boundary_fun = bf.constant,
                            boundary_multiplicative = True, 
                            boundary_params = {})
                            #boundary_params = {"theta": 0.01})
# data = np.concatenate((out[0].T, out[1].T), axis=1).reshape(1,-1)  

# X_train = np.array(X_train)         
# param = np.concatenate((a.reshape(-1, 1), v.reshape(-1, 1)), axis=1)

# print(out[0])
    
a = tf.convert_to_tensor(out[0].reshape(1,500), dtype=tf.float32)
print(a.shape)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta1_power
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta2_power
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.0.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.1.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.2.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.3.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.4.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.5.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.6.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-0._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-1._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-2._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-3._callable_losses
# WARNING:tensorflow:Unresolved object in checkpoint: (root).net.cINNs.7.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.0.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.1.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).net.cINNs.2.s2.dense.layer-0.kernel
# ...
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.4.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.5.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.6.t2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t1.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.s2.dense.layer-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).net.cINNs.7.t2.dense.layer-3.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# (1, 500)

# %%
samples_theta = model.sample(a, 5000).numpy()
# print(samples_theta)
# print(samples_theta)
b = pd.qcut(samples_theta[:, 0], q=10)

df = pd.DataFrame(
    samples_theta[:, 0],
    columns = ['a'])

df.plot.hist(bins=20, alpha=0.5)

var = pd.DataFrame(
    samples_theta[:, 1],
    columns = ['v'])

var.plot.hist(bins=20, alpha=0.5)

# %%
np.mean(samples_theta, axis=0)
# Out:
# array([2.0710387 , 0.23769441], dtype=float32)
